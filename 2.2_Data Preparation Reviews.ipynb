# %%
import polars as pl
import os
from datetime import datetime, timezone
import re
from helper_functions import clean_parquet_files

def preprocess_review(review):
    # Remove non-European characters
    review = re.sub(r'[^\x00-\x7F]', '', review)
    # Remove newline and carriage return characters
    review = review.replace('\n', '').replace('\r', '')
    return review

def preprocess_gamereviews(gamereviews_dict):
    # Preprocess the review
    gamereviews_dict["review"] = preprocess_review(gamereviews_dict.get("review", ""))
    
    # Skip rows with reviews less than 20 characters
    if len(gamereviews_dict["review"]) < 20:
        return None
    
    # Format timestamps
    gamereviews_dict["timestamp_created"] = datetime.fromtimestamp(gamereviews_dict.get("timestamp_created", 0), tz=timezone.utc)
    gamereviews_dict["timestamp_updated"] = datetime.fromtimestamp(gamereviews_dict.get("timestamp_updated", 0), tz=timezone.utc)
    
    # Ensure author field is not None
    author = gamereviews_dict.get("author", {})
    
    # Unpack nested author fields
    gamereviews_dict["user_steamid"] = author.get("steamid", "")
    gamereviews_dict["user_num_games_owned"] = author.get("num_games_owned", 0)
    gamereviews_dict["user_num_reviews"] = author.get("num_reviews", 0)
    gamereviews_dict["user_playtime_forever"] = author.get("playtime_forever", 0)
    
    # Remove unnecessary fields
    gamereviews_dict.pop("author", None)
    gamereviews_dict.pop("author_last_played", None)
    gamereviews_dict.pop("language", None)
    gamereviews_dict.pop("hidden_in_steam_china", None)
    gamereviews_dict.pop("steam_china_location", None)
    
    # Format boolean and float fields
    gamereviews_dict["voted_up"] = bool(gamereviews_dict.get("voted_up", False))
    gamereviews_dict["steam_purchase"] = bool(gamereviews_dict.get("steam_purchase", False))
    gamereviews_dict["received_for_free"] = bool(gamereviews_dict.get("received_for_free", False))
    gamereviews_dict["written_during_early_access"] = bool(gamereviews_dict.get("written_during_early_access", False))
    gamereviews_dict["weighted_vote_score"] = float(gamereviews_dict.get("weighted_vote_score", 0.0))
    
    # Convert back to a DataFrame row
    return gamereviews_dict

def preprocess_parquet_file(filepath, output_filepath, appid):
    # Read the parquet file
    df = pl.read_parquet(filepath)
    
    # Apply preprocessing to each row
    preprocessed_data = [preprocess_gamereviews(row) for row in df.iter_rows(named=True) if row is not None]
    
    # Filter out None values (reviews less than 20 characters)
    preprocessed_data = [row for row in preprocessed_data if row is not None]
    
    # Create a new DataFrame from preprocessed data
    if preprocessed_data:
        preprocessed_df = pl.DataFrame(preprocessed_data)
        
        # Add the appid column
        preprocessed_df = preprocessed_df.with_columns(pl.lit(appid).alias('appid'))
        
        # Check for duplicates
        preprocessed_df = preprocessed_df.unique()
        
        # Write the processed file
        preprocessed_df.write_parquet(output_filepath)

input_folder = 'data/parquets'
output_folder = 'data/parquets_preprocessed'

clean_parquet_files(input_folder)

for file_name in os.listdir(input_folder):
    match = re.match(r"(\d+)_reviews_\d+\.parquet", file_name)
    if match:
        appid = match.group(1)
        input_filepath = os.path.join(input_folder, file_name)
        output_filepath = os.path.join(output_folder, file_name.replace('.parquet', '_preprocessed.parquet'))
        
        # Check if the processed file already exists
        if not os.path.exists(output_filepath):
            preprocess_parquet_file(input_filepath, output_filepath, appid)
# Out:
# Files kept:
# Kept: 1000760_reviews_490.parquet with count: 490
# Kept: 1011190_reviews_547.parquet with count: 547
# Kept: 1012110_reviews_447.parquet with count: 447
# Kept: 1027820_reviews_260.parquet with count: 260
# Kept: 104600_reviews_422.parquet with count: 422
# Kept: 1061180_reviews_520.parquet with count: 520
# Kept: 1062960_reviews_567.parquet with count: 567
# Kept: 1064460_reviews_1176.parquet with count: 1176
# Kept: 1065310_reviews_3042.parquet with count: 3042
# Kept: 1069740_reviews_3270.parquet with count: 3270
# Kept: 1070710_reviews_5875.parquet with count: 5875
# Kept: 1075740_reviews_1133.parquet with count: 1133
# Kept: 1077290_reviews_457.parquet with count: 457
# Kept: 1082430_reviews_9192.parquet with count: 9192
# Kept: 1085660_reviews_71741.parquet with count: 71741
# Kept: 1086640_reviews_616.parquet with count: 616
# Kept: 1086940_reviews_335231.parquet with count: 335231
# Kept: 1088790_reviews_2014.parquet with count: 2014
# Kept: 1091500_reviews_44700.parquet with count: 44700
# Kept: 1091920_reviews_390.parquet with count: 390
# Kept: 1093910_reviews_868.parquet with count: 868
# Kept: 1096720_reviews_337.parquet with count: 337
# Kept: 1098340_reviews_406.parquet with count: 406
# Kept: 1099640_reviews_340.parquet with count: 340
# Kept: 10_reviews_30585.parquet with count: 30585
# Kept: 1100990_reviews_1148.parquet with count: 1148
# Kept: 1101190_reviews_2172.parquet with count: 2172
# Kept: 1101450_reviews_680.parquet with count: 680
# Kept: 1119700_reviews_471.parquet with count: 471
# Kept: 1133060_reviews_270.parquet with count: 270
# Kept: 11390_reviews_409.parquet with count: 409
# Kept: 1139890_reviews_2037.parquet with count: 2037
# Kept: 1142710_reviews_40812.parquet with count: 40812
# Kept: 1144030_reviews_1054.parquet with count: 1054
# Kept: 1145350_reviews_16168.parquet with count: 16168
# Kept: 1145960_reviews_1275.parquet with count: 1275
# Kept: 1149660_reviews_264.parquet with count: 264
# Kept: 1151340_reviews_32037.parquet with count: 32037
# Kept: 1153430_reviews_266.parquet with count: 266
# Kept: 1158310_reviews_4100.parquet with count: 4100
# Kept: 1162680_reviews_455.parquet with count: 455
# Kept: 1162960_reviews_402.parquet with count: 402
# Kept: 1164850_reviews_280.parquet with count: 280
# Kept: 1172470_reviews_957.parquet with count: 957
# Kept: 1172620_reviews_118300.parquet with count: 118300
# Kept: 1177980_reviews_1551.parquet with count: 1551
# Kept: 1184160_reviews_1145.parquet with count: 1145
# Kept: 1194590_reviews_293.parquet with count: 293
# Kept: 1197370_reviews_392.parquet with count: 392
# Kept: 1200_reviews_684.parquet with count: 684
# Kept: 1201830_reviews_310.parquet with count: 310
# Kept: 1202900_reviews_2993.parquet with count: 2993
# Kept: 1203420_reviews_435.parquet with count: 435
# Kept: 1205040_reviews_396.parquet with count: 396
# Kept: 1205960_reviews_413.parquet with count: 413
# Kept: 1210320_reviews_10979.parquet with count: 10979
# Kept: 1212620_reviews_670.parquet with count: 670
# Kept: 1218900_reviews_755.parquet with count: 755
# Kept: 1222670_reviews_41368.parquet with count: 41368
# Kept: 1222700_reviews_14565.parquet with count: 14565
# Kept: 1225590_reviews_521.parquet with count: 521
# Kept: 1229460_reviews_424.parquet with count: 424
# Kept: 1235140_reviews_11626.parquet with count: 11626
# Kept: 1236990_reviews_1549.parquet with count: 1549
# Kept: 1244460_reviews_12064.parquet with count: 12064
# Kept: 1245620_reviews_254999.parquet with count: 254999
# Kept: 1248130_reviews_19196.parquet with count: 19196
# Kept: 1250410_reviews_36267.parquet with count: 36267
# Kept: 1252330_reviews_11151.parquet with count: 11151
# Kept: 1255650_reviews_366.parquet with count: 366
# Kept: 1257410_reviews_277.parquet with count: 277
# Kept: 1259980_reviews_2258.parquet with count: 2258
# Kept: 1260810_reviews_339.parquet with count: 339
# Kept: 1266820_reviews_267.parquet with count: 267
# Kept: 1275890_reviews_3045.parquet with count: 3045
# Kept: 1284190_reviews_17496.parquet with count: 17496
# Kept: 1285670_reviews_6562.parquet with count: 6562
# Kept: 1296840_reviews_548.parquet with count: 548
# Kept: 1299120_reviews_704.parquet with count: 704
# Kept: 1306620_reviews_270.parquet with count: 270
# Kept: 1318090_reviews_899.parquet with count: 899
# Kept: 1334000_reviews_369.parquet with count: 369
# Kept: 1342890_reviews_489.parquet with count: 489
# Kept: 1345820_reviews_1703.parquet with count: 1703
# Kept: 1347030_reviews_1491.parquet with count: 1491
# Kept: 1349960_reviews_287.parquet with count: 287
# Kept: 13530_reviews_801.parquet with count: 801
# Kept: 13580_reviews_831.parquet with count: 831
# Kept: 1361700_reviews_679.parquet with count: 679
# Kept: 1363080_reviews_18692.parquet with count: 18692
# Kept: 1377360_reviews_354.parquet with count: 354
# Kept: 1377380_reviews_2787.parquet with count: 2787
# Kept: 1386780_reviews_711.parquet with count: 711
# Kept: 1403020_reviews_288.parquet with count: 288
# Kept: 1409530_reviews_381.parquet with count: 381
# Kept: 1421250_reviews_599.parquet with count: 599
# Kept: 1430680_reviews_492.parquet with count: 492
# Kept: 1446330_reviews_256.parquet with count: 256
# Kept: 1472660_reviews_2590.parquet with count: 2590
# Kept: 1473050_reviews_332.parquet with count: 332
# Kept: 1500740_reviews_311.parquet with count: 311
# Kept: 1504020_reviews_1152.parquet with count: 1152
# Kept: 1507190_reviews_421.parquet with count: 421
# Kept: 15080_reviews_694.parquet with count: 694
# Kept: 15130_reviews_1650.parquet with count: 1650
# Kept: 15200_reviews_618.parquet with count: 618
# Kept: 1524630_reviews_256.parquet with count: 256
# Kept: 1531720_reviews_269.parquet with count: 269
# Kept: 1536090_reviews_469.parquet with count: 469
# Kept: 1540210_reviews_564.parquet with count: 564
# Kept: 1555110_reviews_343.parquet with count: 343
# Kept: 1567440_reviews_274.parquet with count: 274
# Kept: 15710_reviews_792.parquet with count: 792
# Kept: 1574240_reviews_891.parquet with count: 891
# Kept: 1587560_reviews_983.parquet with count: 983
# Kept: 1591520_reviews_2335.parquet with count: 2335
# Kept: 1599340_reviews_38881.parquet with count: 38881
# Kept: 1599880_reviews_466.parquet with count: 466
# Kept: 1604030_reviews_37760.parquet with count: 37760
# Kept: 1639790_reviews_2039.parquet with count: 2039
# Kept: 1651560_reviews_1477.parquet with count: 1477
# Kept: 1656780_reviews_1994.parquet with count: 1994
# Kept: 1669000_reviews_6537.parquet with count: 6537
# Kept: 1677280_reviews_8397.parquet with count: 8397
# Kept: 1688580_reviews_403.parquet with count: 403
# Kept: 1690_reviews_293.parquet with count: 293
# Kept: 1716740_reviews_73002.parquet with count: 73002
# Kept: 1718570_reviews_2098.parquet with count: 2098
# Kept: 1722840_reviews_252.parquet with count: 252
# Kept: 1733060_reviews_443.parquet with count: 443
# Kept: 1766390_reviews_401.parquet with count: 401
# Kept: 1774580_reviews_33704.parquet with count: 33704
# Kept: 1794680_reviews_110619.parquet with count: 110619
# Kept: 1797680_reviews_287.parquet with count: 287
# Kept: 18040_reviews_401.parquet with count: 401
# Kept: 1812450_reviews_2212.parquet with count: 2212
# Kept: 1817000_reviews_422.parquet with count: 422
# Kept: 1832640_reviews_2471.parquet with count: 2471
# Kept: 1834920_reviews_336.parquet with count: 336
# Kept: 1840080_reviews_604.parquet with count: 604
# Kept: 1848450_reviews_2282.parquet with count: 2282
# Kept: 1849250_reviews_3024.parquet with count: 3024
# Kept: 1853200_reviews_1606.parquet with count: 1606
# Kept: 1862520_reviews_264.parquet with count: 264
# Kept: 1889040_reviews_1355.parquet with count: 1355
# Kept: 1901370_reviews_1110.parquet with count: 1110
# Kept: 1902710_reviews_290.parquet with count: 290
# Kept: 1910680_reviews_945.parquet with count: 945
# Kept: 1916970_reviews_372.parquet with count: 372
# Kept: 1919460_reviews_938.parquet with count: 938
# Kept: 1919550_reviews_296.parquet with count: 296
# Kept: 1927720_reviews_925.parquet with count: 925
# Kept: 1929870_reviews_777.parquet with count: 777
# Kept: 1930600_reviews_292.parquet with count: 292
# Kept: 1938090_reviews_156500.parquet with count: 156500
# Kept: 1944570_reviews_3602.parquet with count: 3602
# Kept: 1949960_reviews_1117.parquet with count: 1117
# Kept: 1950440_reviews_572.parquet with count: 572
# Kept: 1954200_reviews_4754.parquet with count: 4754
# Kept: 1956040_reviews_981.parquet with count: 981
# Kept: 1962663_reviews_3158.parquet with count: 3158
# Kept: 19980_reviews_1452.parquet with count: 1452
# Kept: 2024230_reviews_626.parquet with count: 626
# Kept: 204630_reviews_1054.parquet with count: 1054
# Kept: 206440_reviews_17459.parquet with count: 17459
# Kept: 2066020_reviews_8125.parquet with count: 8125
# Kept: 207430_reviews_257.parquet with count: 257
# Kept: 208580_reviews_15862.parquet with count: 15862
# Kept: 2088840_reviews_1085.parquet with count: 1085
# Kept: 20900_reviews_19618.parquet with count: 19618
# Kept: 20_reviews_3707.parquet with count: 3707
# Kept: 211260_reviews_1346.parquet with count: 1346
# Kept: 211780_reviews_676.parquet with count: 676
# Kept: 2134770_reviews_555.parquet with count: 555
# Kept: 214170_reviews_1275.parquet with count: 1275
# Kept: 2181720_reviews_466.parquet with count: 466
# Kept: 2195250_reviews_19807.parquet with count: 19807
# Kept: 219830_reviews_1816.parquet with count: 1816
# Kept: 219950_reviews_713.parquet with count: 713
# Kept: 2208920_reviews_7565.parquet with count: 7565
# Kept: 22100_reviews_1931.parquet with count: 1931
# Kept: 221100_reviews_101600.parquet with count: 101600
# Kept: 22180_reviews_1647.parquet with count: 1647
# Kept: 2236300_reviews_285.parquet with count: 285
# Kept: 224500_reviews_2080.parquet with count: 2080
# Kept: 224940_reviews_422.parquet with count: 422
# Kept: 226560_reviews_346.parquet with count: 346
# Kept: 227300_reviews_75500.parquet with count: 75500
# Kept: 2292260_reviews_515.parquet with count: 515
# Kept: 230410_reviews_1122.parquet with count: 1122
# Kept: 230840_reviews_504.parquet with count: 504
# Kept: 2313240_reviews_646.parquet with count: 646
# Kept: 233350_reviews_415.parquet with count: 415
# Kept: 234390_reviews_746.parquet with count: 746
# Kept: 23490_reviews_430.parquet with count: 430
# Kept: 235540_reviews_7630.parquet with count: 7630
# Kept: 2356500_reviews_439.parquet with count: 439
# Kept: 236390_reviews_283.parquet with count: 283
# Kept: 236430_reviews_14014.parquet with count: 14014
# Kept: 2367230_reviews_278.parquet with count: 278
# Kept: 237630_reviews_2991.parquet with count: 2991
# Kept: 237740_reviews_1924.parquet with count: 1924
# Kept: 239200_reviews_3908.parquet with count: 3908
# Kept: 239430_reviews_510.parquet with count: 510
# Kept: 242940_reviews_267.parquet with count: 267
# Kept: 242960_reviews_541.parquet with count: 541
# Kept: 242980_reviews_447.parquet with count: 447
# Kept: 243930_reviews_1413.parquet with count: 1413
# Kept: 2449040_reviews_360.parquet with count: 360
# Kept: 247430_reviews_1050.parquet with count: 1050
# Kept: 247950_reviews_732.parquet with count: 732
# Kept: 2479810_reviews_1906.parquet with count: 1906
# Kept: 249680_reviews_987.parquet with count: 987
# Kept: 2499470_reviews_504.parquet with count: 504
# Kept: 250520_reviews_4108.parquet with count: 4108
# Kept: 251430_reviews_389.parquet with count: 389
# Kept: 2519060_reviews_5398.parquet with count: 5398
# Kept: 252630_reviews_1167.parquet with count: 1167
# Kept: 2532550_reviews_614.parquet with count: 614
# Kept: 2536530_reviews_343.parquet with count: 343
# Kept: 2551170_reviews_437.parquet with count: 437
# Kept: 255320_reviews_388.parquet with count: 388
# Kept: 255710_reviews_90325.parquet with count: 90325
# Kept: 257510_reviews_15523.parquet with count: 15523
# Kept: 258010_reviews_453.parquet with count: 453
# Kept: 25990_reviews_333.parquet with count: 333
# Kept: 260570_reviews_326.parquet with count: 326
# Kept: 261530_reviews_1460.parquet with count: 1460
# Kept: 263560_reviews_339.parquet with count: 339
# Kept: 265890_reviews_2703.parquet with count: 2703
# Kept: 266210_reviews_2383.parquet with count: 2383
# Kept: 2670630_reviews_11262.parquet with count: 11262
# Kept: 268650_reviews_8119.parquet with count: 8119
# Kept: 269670_reviews_592.parquet with count: 592
# Kept: 270110_reviews_482.parquet with count: 482
# Kept: 270150_reviews_4729.parquet with count: 4729
# Kept: 271240_reviews_2534.parquet with count: 2534
# Kept: 272040_reviews_339.parquet with count: 339
# Kept: 272600_reviews_1235.parquet with count: 1235
# Kept: 273500_reviews_429.parquet with count: 429
# Kept: 274290_reviews_1395.parquet with count: 1395
# Kept: 275570_reviews_285.parquet with count: 285
# Kept: 279440_reviews_298.parquet with count: 298
# Kept: 2810_reviews_267.parquet with count: 267
# Kept: 281920_reviews_626.parquet with count: 626
# Kept: 281940_reviews_404.parquet with count: 404
# Kept: 281990_reviews_64501.parquet with count: 64501
# Kept: 283940_reviews_368.parquet with count: 368
# Kept: 283980_reviews_310.parquet with count: 310
# Kept: 284750_reviews_487.parquet with count: 487
# Kept: 2881650_reviews_9477.parquet with count: 9477
# Kept: 290080_reviews_4241.parquet with count: 4241
# Kept: 292930_reviews_382.parquet with count: 382
# Kept: 294100_reviews_94615.parquet with count: 94615
# Kept: 296490_reviews_2306.parquet with count: 2306
# Kept: 296870_reviews_703.parquet with count: 703
# Kept: 298030_reviews_2132.parquet with count: 2132
# Kept: 299460_reviews_712.parquet with count: 712
# Kept: 299720_reviews_473.parquet with count: 473
# Kept: 300060_reviews_594.parquet with count: 594
# Kept: 302080_reviews_608.parquet with count: 608
# Kept: 306020_reviews_6716.parquet with count: 6716
# Kept: 306130_reviews_38100.parquet with count: 38100
# Kept: 30_reviews_1948.parquet with count: 1948
# Kept: 312840_reviews_1620.parquet with count: 1620
# Kept: 315460_reviews_1993.parquet with count: 1993
# Kept: 316430_reviews_944.parquet with count: 944
# Kept: 318130_reviews_1096.parquet with count: 1096
# Kept: 32380_reviews_1207.parquet with count: 1207
# Kept: 32390_reviews_554.parquet with count: 554
# Kept: 327410_reviews_2624.parquet with count: 2624
# Kept: 3300_reviews_392.parquet with count: 392
# Kept: 3320_reviews_3630.parquet with count: 3630
# Kept: 332950_reviews_410.parquet with count: 410
# Kept: 334230_reviews_24328.parquet with count: 24328
# Kept: 336610_reviews_259.parquet with count: 259
# Kept: 338390_reviews_1405.parquet with count: 1405
# Kept: 3390_reviews_862.parquet with count: 862
# Kept: 33930_reviews_8662.parquet with count: 8662
# Kept: 339580_reviews_684.parquet with count: 684
# Kept: 34190_reviews_1208.parquet with count: 1208
# Kept: 3450_reviews_292.parquet with count: 292
# Kept: 345200_reviews_252.parquet with count: 252
# Kept: 345240_reviews_555.parquet with count: 555
# Kept: 347670_reviews_383.parquet with count: 383
# Kept: 34830_reviews_1707.parquet with count: 1707
# Kept: 35000_reviews_1224.parquet with count: 1224
# Kept: 351030_reviews_289.parquet with count: 289
# Kept: 351920_reviews_2334.parquet with count: 2334
# Kept: 352520_reviews_2645.parquet with count: 2645
# Kept: 353330_reviews_568.parquet with count: 568
# Kept: 353640_reviews_1163.parquet with count: 1163
# Kept: 355050_reviews_714.parquet with count: 714
# Kept: 355170_reviews_525.parquet with count: 525
# Kept: 355250_reviews_395.parquet with count: 395
# Kept: 355800_reviews_440.parquet with count: 440
# Kept: 357070_reviews_1180.parquet with count: 1180
# Kept: 358750_reviews_415.parquet with count: 415
# Kept: 359050_reviews_4640.parquet with count: 4640
# Kept: 359550_reviews_32700.parquet with count: 32700
# Kept: 360640_reviews_534.parquet with count: 534
# Kept: 362930_reviews_8334.parquet with count: 8334
# Kept: 364420_reviews_1851.parquet with count: 1851
# Kept: 366910_reviews_538.parquet with count: 538
# Kept: 369530_reviews_526.parquet with count: 526
# Kept: 370360_reviews_2317.parquet with count: 2317
# Kept: 370910_reviews_1155.parquet with count: 1155
# Kept: 3720_reviews_2241.parquet with count: 2241
# Kept: 374280_reviews_475.parquet with count: 475
# Kept: 374320_reviews_82399.parquet with count: 82399
# Kept: 377160_reviews_146846.parquet with count: 146846
# Kept: 381210_reviews_196881.parquet with count: 196881
# Kept: 386360_reviews_752.parquet with count: 752
# Kept: 388060_reviews_300.parquet with count: 300
# Kept: 388090_reviews_7435.parquet with count: 7435
# Kept: 39200_reviews_1162.parquet with count: 1162
# Kept: 39210_reviews_52381.parquet with count: 52381
# Kept: 394360_reviews_97495.parquet with count: 97495
# Kept: 396480_reviews_543.parquet with count: 543
# Kept: 397350_reviews_1011.parquet with count: 1011
# Kept: 398710_reviews_1673.parquet with count: 1673
# Kept: 400110_reviews_251.parquet with count: 251
# Kept: 401190_reviews_1564.parquet with count: 1564
# Kept: 402040_reviews_353.parquet with count: 353
# Kept: 403120_reviews_1321.parquet with count: 1321
# Kept: 406290_reviews_1261.parquet with count: 1261
# Kept: 40720_reviews_628.parquet with count: 628
# Kept: 409660_reviews_489.parquet with count: 489
# Kept: 40990_reviews_1871.parquet with count: 1871
# Kept: 40_reviews_1117.parquet with count: 1117
# Kept: 410110_reviews_997.parquet with count: 997
# Kept: 412880_reviews_1415.parquet with count: 1415
# Kept: 413150_reviews_300385.parquet with count: 300385
# Kept: 414720_reviews_372.parquet with count: 372
# Kept: 416590_reviews_884.parquet with count: 884
# Kept: 419460_reviews_929.parquet with count: 929
# Kept: 42210_reviews_255.parquet with count: 255
# Kept: 422910_reviews_558.parquet with count: 558
# Kept: 427290_reviews_7458.parquet with count: 7458
# Kept: 427820_reviews_836.parquet with count: 836
# Kept: 428550_reviews_3847.parquet with count: 3847
# Kept: 42890_reviews_459.parquet with count: 459
# Kept: 431590_reviews_333.parquet with count: 333
# Kept: 434650_reviews_1345.parquet with count: 1345
# Kept: 434730_reviews_1132.parquet with count: 1132
# Kept: 435150_reviews_74683.parquet with count: 74683
# Kept: 436520_reviews_1192.parquet with count: 1192
# Kept: 438480_reviews_552.parquet with count: 552
# Kept: 440730_reviews_410.parquet with count: 410
# Kept: 444640_reviews_262.parquet with count: 262
# Kept: 445110_reviews_282.parquet with count: 282
# Kept: 446790_reviews_491.parquet with count: 491
# Kept: 449710_reviews_311.parquet with count: 311
# Kept: 45100_reviews_525.parquet with count: 525
# Kept: 454060_reviews_681.parquet with count: 681
# Kept: 455400_reviews_689.parquet with count: 689
# Kept: 457680_reviews_329.parquet with count: 329
# Kept: 460120_reviews_1445.parquet with count: 1445
# Kept: 460920_reviews_9787.parquet with count: 9787
# Kept: 463980_reviews_251.parquet with count: 251
# Kept: 466240_reviews_742.parquet with count: 742
# Kept: 48000_reviews_10499.parquet with count: 10499
# Kept: 483980_reviews_1945.parquet with count: 1945
# Kept: 485380_reviews_1492.parquet with count: 1492
# Kept: 485610_reviews_774.parquet with count: 774
# Kept: 48720_reviews_3087.parquet with count: 3087
# Kept: 495110_reviews_297.parquet with count: 297
# Kept: 498330_reviews_489.parquet with count: 489
# Kept: 500810_reviews_958.parquet with count: 958
# Kept: 501320_reviews_459.parquet with count: 459
# Kept: 501790_reviews_520.parquet with count: 520
# Kept: 504770_reviews_448.parquet with count: 448
# Kept: 505640_reviews_389.parquet with count: 389
# Kept: 506730_reviews_298.parquet with count: 298
# Kept: 508900_reviews_1195.parquet with count: 1195
# Kept: 50_reviews_10408.parquet with count: 10408
# Kept: 512250_reviews_2641.parquet with count: 2641
# Kept: 513510_reviews_1623.parquet with count: 1623
# Kept: 515040_reviews_1090.parquet with count: 1090
# Kept: 524910_reviews_789.parquet with count: 789
# Kept: 525620_reviews_589.parquet with count: 589
# Kept: 527230_reviews_10635.parquet with count: 10635
# Kept: 527450_reviews_832.parquet with count: 832
# Kept: 529340_reviews_15190.parquet with count: 15190
# Kept: 531930_reviews_335.parquet with count: 335
# Kept: 532110_reviews_1413.parquet with count: 1413
# Kept: 533300_reviews_2083.parquet with count: 2083
# Kept: 534550_reviews_1156.parquet with count: 1156
# Kept: 540840_reviews_1137.parquet with count: 1137
# Kept: 544550_reviews_3707.parquet with count: 3707
# Kept: 545040_reviews_258.parquet with count: 258
# Kept: 549860_reviews_342.parquet with count: 342
# Kept: 552990_reviews_756.parquet with count: 756
# Kept: 553850_reviews_491546.parquet with count: 491546
# Kept: 556180_reviews_291.parquet with count: 291
# Kept: 560170_reviews_450.parquet with count: 450
# Kept: 560430_reviews_479.parquet with count: 479
# Kept: 562810_reviews_7881.parquet with count: 7881
# Kept: 566160_reviews_608.parquet with count: 608
# Kept: 570940_reviews_33983.parquet with count: 33983
# Kept: 570_reviews_6066.parquet with count: 6066
# Kept: 573090_reviews_31565.parquet with count: 31565
# Kept: 573120_reviews_487.parquet with count: 487
# Kept: 575640_reviews_1439.parquet with count: 1439
# Kept: 575950_reviews_258.parquet with count: 258
# Kept: 57640_reviews_992.parquet with count: 992
# Kept: 577230_reviews_314.parquet with count: 314
# Kept: 577670_reviews_406.parquet with count: 406
# Kept: 577940_reviews_2034.parquet with count: 2034
# Kept: 578080_reviews_113399.parquet with count: 113399
# Kept: 578900_reviews_418.parquet with count: 418
# Kept: 579020_reviews_264.parquet with count: 264
# Kept: 580720_reviews_623.parquet with count: 623
# Kept: 582660_reviews_32571.parquet with count: 32571
# Kept: 583760_reviews_285.parquet with count: 285
# Kept: 585690_reviews_538.parquet with count: 538
# Kept: 585840_reviews_481.parquet with count: 481
# Kept: 589530_reviews_501.parquet with count: 501
# Kept: 591420_reviews_725.parquet with count: 725
# Kept: 597230_reviews_375.parquet with count: 375
# Kept: 598810_reviews_851.parquet with count: 851
# Kept: 601220_reviews_1389.parquet with count: 1389
# Kept: 602320_reviews_1000.parquet with count: 1000
# Kept: 6040_reviews_674.parquet with count: 674
# Kept: 610360_reviews_566.parquet with count: 566
# Kept: 617700_reviews_508.parquet with count: 508
# Kept: 618140_reviews_523.parquet with count: 523
# Kept: 6200_reviews_920.parquet with count: 920
# Kept: 624970_reviews_575.parquet with count: 575
# Kept: 629220_reviews_278.parquet with count: 278
# Kept: 638850_reviews_597.parquet with count: 597
# Kept: 63940_reviews_468.parquet with count: 468
# Kept: 645090_reviews_663.parquet with count: 663
# Kept: 654900_reviews_303.parquet with count: 303
# Kept: 654990_reviews_701.parquet with count: 701
# Kept: 657240_reviews_875.parquet with count: 875
# Kept: 65780_reviews_368.parquet with count: 368
# Kept: 65790_reviews_905.parquet with count: 905
# Kept: 658550_reviews_260.parquet with count: 260
# Kept: 658560_reviews_478.parquet with count: 478
# Kept: 662960_reviews_258.parquet with count: 258
# Kept: 665360_reviews_4780.parquet with count: 4780
# Kept: 666330_reviews_332.parquet with count: 332
# Kept: 667600_reviews_908.parquet with count: 908
# Kept: 673450_reviews_303.parquet with count: 303
# Kept: 673800_reviews_320.parquet with count: 320
# Kept: 6830_reviews_870.parquet with count: 870
# Kept: 6870_reviews_394.parquet with count: 394
# Kept: 687260_reviews_546.parquet with count: 546
# Kept: 6920_reviews_1344.parquet with count: 1344
# Kept: 699920_reviews_305.parquet with count: 305
# Kept: 70100_reviews_257.parquet with count: 257
# Kept: 7010_reviews_318.parquet with count: 318
# Kept: 712100_reviews_6552.parquet with count: 6552
# Kept: 71240_reviews_398.parquet with count: 398
# Kept: 71260_reviews_672.parquet with count: 672
# Kept: 728880_reviews_698.parquet with count: 698
# Kept: 730_reviews_266799.parquet with count: 266799
# Kept: 746400_reviews_376.parquet with count: 376
# Kept: 748300_reviews_364.parquet with count: 364
# Kept: 7600_reviews_1569.parquet with count: 1569
# Kept: 765410_reviews_5672.parquet with count: 5672
# Kept: 771350_reviews_309.parquet with count: 309
# Kept: 774861_reviews_4631.parquet with count: 4631
# Kept: 780210_reviews_1151.parquet with count: 1151
# Kept: 794540_reviews_774.parquet with count: 774
# Kept: 799070_reviews_773.parquet with count: 773
# Kept: 800600_reviews_288.parquet with count: 288
# Kept: 805550_reviews_10236.parquet with count: 10236
# Kept: 805940_reviews_936.parquet with count: 936
# Kept: 806140_reviews_384.parquet with count: 384
# Kept: 813230_reviews_3777.parquet with count: 3777
# Kept: 824190_reviews_285.parquet with count: 285
# Kept: 825310_reviews_526.parquet with count: 526
# Kept: 828900_reviews_495.parquet with count: 495
# Kept: 829110_reviews_2034.parquet with count: 2034
# Kept: 829280_reviews_532.parquet with count: 532
# Kept: 833040_reviews_1044.parquet with count: 1044
# Kept: 838310_reviews_1768.parquet with count: 1768
# Kept: 838380_reviews_1390.parquet with count: 1390
# Kept: 853550_reviews_2002.parquet with count: 2002
# Kept: 8600_reviews_499.parquet with count: 499
# Kept: 860950_reviews_2144.parquet with count: 2144
# Kept: 870780_reviews_300.parquet with count: 300
# Kept: 881690_reviews_334.parquet with count: 334
# Kept: 882790_reviews_253.parquet with count: 253
# Kept: 896160_reviews_845.parquet with count: 845
# Kept: 896460_reviews_297.parquet with count: 297
# Kept: 897030_reviews_916.parquet with count: 916
# Kept: 916730_reviews_1718.parquet with count: 1718
# Kept: 92100_reviews_436.parquet with count: 436
# Kept: 921590_reviews_424.parquet with count: 424
# Kept: 923260_reviews_289.parquet with count: 289
# Kept: 924140_reviews_2841.parquet with count: 2841
# Kept: 92800_reviews_1796.parquet with count: 1796
# Kept: 932850_reviews_735.parquet with count: 735
# Kept: 935880_reviews_913.parquet with count: 913
# Kept: 939400_reviews_1904.parquet with count: 1904
# Kept: 942970_reviews_2405.parquet with count: 2405
# Kept: 945360_reviews_127699.parquet with count: 127699
# Kept: 94590_reviews_364.parquet with count: 364
# Kept: 9460_reviews_392.parquet with count: 392
# Kept: 952040_reviews_928.parquet with count: 928
# Kept: 958400_reviews_1026.parquet with count: 1026
# Kept: 965310_reviews_256.parquet with count: 256
# Kept: 971680_reviews_495.parquet with count: 495
# Kept: 976010_reviews_341.parquet with count: 341
# Kept: 982720_reviews_688.parquet with count: 688
# Kept: 983870_reviews_551.parquet with count: 551
# Kept: 994220_reviews_592.parquet with count: 592
